# %%
import pandas as pd
import numpy as np
import psycopg2
from sqlalchemy import create_engine
import config

# %%
# Create a connection
conn = psycopg2.connect(
    host=config.host,
    port=config.port,
    dbname=config.dbname,
    user=config.user,
    password=config.password
)
# Create a cursor object
cur = conn.cursor()

# %%
engine = create_engine(f'postgresql+psycopg2://{config.user}:{config.password}@{config.host}:{config.port}/{config.dbname}')

# %%
df = pd.read_sql_query('SELECT * FROM trips', con=engine)

# %%
df.head(15)
# Out:
#              ride_id  rideable_type           started_at             ended_at  \
# 0   000AC620FBE17FDF   classic_bike  2023-03-27 08:11:49  2023-03-27 08:16:32
# 1   000E4EFD90D2F381   classic_bike  2023-03-30 16:24:04  2023-03-30 16:26:23
# 2   000FA514F5399724   classic_bike  2023-03-05 12:16:07  2023-03-05 12:22:00
# 3   0016859A2B067DD3   classic_bike  2023-03-03 11:16:25  2023-03-03 11:17:12
# 4   001F047AA8074A86   classic_bike  2023-03-30 17:29:06  2023-03-30 17:41:54
# 5   00223A1B18DAE98E   classic_bike  2023-03-09 15:02:32  2023-03-09 15:09:52
# 6   0022E8494016CF17   classic_bike  2023-03-07 18:11:11  2023-03-07 18:17:52
# 7   00304EFC3104BD09   classic_bike  2023-03-08 15:46:10  2023-03-08 15:46:52
# 8   00306F7BA3A36ADF   classic_bike  2023-03-11 16:56:59  2023-03-11 17:03:06
# 9   003614BC584DF537   classic_bike  2023-03-14 06:37:59  2023-03-14 06:55:27
# 10  00369DDE40CDB794  electric_bike  2023-03-08 00:51:29  2023-03-08 01:00:44
# ...

# %%
df.shape
# Out:
# (2194214, 13)

# %%
df.ride_id.value_counts()
# Out:
# 000AC620FBE17FDF    1
# B60166FD5188B3FF    1
# B645EBEEE99E95E5    1
# B6451C4149816E45    1
# B63DBE53BAB20F27    1
#                    ..
# 502827F192D0E0BC    1
# 5024864BD1F062F7    1
# 501D7A8C25054CDA    1
# 501C29D715964D9D    1
# FFF8FE9FB05BB96C    1
# Name: ride_id, Length: 2194214, dtype: int64

# %%
df.isna().sum()
# Out:
# ride_id                  0
# rideable_type            0
# started_at               0
# ended_at                 0
# start_station_name     190
# start_station_id       190
# end_station_name      5794
# end_station_id        5794
# start_lat                0
# start_lng                0
# end_lat               1481
# end_lng               1481
# member_casual            0
# dtype: int64

# %%
df2 = pd.read_sql_query('SELECT * FROM station_information', con=engine)

# %%
df2.shape
# Out:
# (1866, 14)

# %%
df2
# Out:
#                                external_id  \
# 0     66de19ab-0aca-11e7-82f6-3863bb44ef7c
# 1     66dd26f9-0aca-11e7-82f6-3863bb44ef7c
# 2     66dd3e14-0aca-11e7-82f6-3863bb44ef7c
# 3     0dd71c6d-11ee-4ad4-ba99-36b9ad36112c
# 4     bc9c9006-3d40-400d-8b5c-17f56e6dfcee
# ...                                    ...
# 1861  519824e4-69ba-4270-a395-17c204f328f8
# 1862  cbc48689-7805-49dd-9669-5471f4b7b6fb
# 1863  66dddd28-0aca-11e7-82f6-3863bb44ef7c
# 1864  b6a13f2b-deb4-4f4d-9d67-7d23bee27c88
# 1865  5aa81a37-ea1d-4bf6-ab40-4751c6b4fb08
#
#                                 station_id  electric_bike_surcharge_waiver  \
# 0     66de19ab-0aca-11e7-82f6-3863bb44ef7c                           False
# 1     66dd26f9-0aca-11e7-82f6-3863bb44ef7c                           False
# 2     66dd3e14-0aca-11e7-82f6-3863bb44ef7c                           False
# 3     0dd71c6d-11ee-4ad4-ba99-36b9ad36112c                           False
# ...

# %%
df2.drop_duplicates().shape
# Out:
# (1866, 14)

# %%
df2.isna().sum()
# Out:
# external_id                       0
# station_id                        0
# electric_bike_surcharge_waiver    0
# short_name                        0
# eightd_has_key_dispenser          0
# name                              0
# lat                               0
# region_id                         0
# lon                               0
# capacity                          0
# has_kiosk                         0
# station_type                      0
# rental_methods                    0
# legacy_id                         0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['external_id', 'station_id', 'electric_bike_surcharge_waiver',
#        'short_name', 'eightd_has_key_dispenser', 'name', 'lat', 'region_id',
#        'lon', 'capacity', 'has_kiosk', 'station_type', 'rental_methods',
#        'legacy_id'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        000AC620FBE17FDF   classic_bike  2023-03-27 08:11:49
# 1        000E4EFD90D2F381   classic_bike  2023-03-30 16:24:04
# 2        000FA514F5399724   classic_bike  2023-03-05 12:16:07
# 3        0016859A2B067DD3   classic_bike  2023-03-03 11:16:25
# 4        001F047AA8074A86   classic_bike  2023-03-30 17:29:06
# ...                   ...            ...                  ...
# 2194209  FFDC3D0C8C1F1601   classic_bike  2023-03-08 08:07:40
# 2194210  FFDD0ECFD80B6464  electric_bike  2023-03-24 03:06:11
# 2194211  FFF18A9BE822C86C  electric_bike  2023-03-18 11:31:23
# 2194212  FFF3143A285B9F81   classic_bike  2023-03-05 17:22:55
# 2194213  FFF8FE9FB05BB96C   classic_bike  2023-03-18 10:53:50
#
#                     ended_at       start_station_name start_station_id  \
# 0        2023-03-27 08:16:32         2 Ave & E 122 St          7622.12
# 1        2023-03-30 16:26:23           30 St & 48 Ave          6076.02
# ...

# %%
df2.
# Out:
#                                external_id  \
# 0     66de19ab-0aca-11e7-82f6-3863bb44ef7c
# 1     66dd26f9-0aca-11e7-82f6-3863bb44ef7c
# 2     66dd3e14-0aca-11e7-82f6-3863bb44ef7c
# 3     0dd71c6d-11ee-4ad4-ba99-36b9ad36112c
# 4     bc9c9006-3d40-400d-8b5c-17f56e6dfcee
# ...                                    ...
# 1861  519824e4-69ba-4270-a395-17c204f328f8
# 1862  cbc48689-7805-49dd-9669-5471f4b7b6fb
# 1863  66dddd28-0aca-11e7-82f6-3863bb44ef7c
# 1864  b6a13f2b-deb4-4f4d-9d67-7d23bee27c88
# 1865  5aa81a37-ea1d-4bf6-ab40-4751c6b4fb08
#
#                                 station_id  electric_bike_surcharge_waiver  \
# 0     66de19ab-0aca-11e7-82f6-3863bb44ef7c                           False
# 1     66dd26f9-0aca-11e7-82f6-3863bb44ef7c                           False
# 2     66dd3e14-0aca-11e7-82f6-3863bb44ef7c                           False
# 3     0dd71c6d-11ee-4ad4-ba99-36b9ad36112c                           False
# ...

# %%
bike_trip_facts = pd.read_sql_query('SELECT * FROM biketrips_fact', con=engine)

# %%
bike_trip_facts.head()
# Out:
#             trip_id   date_id start_station_id end_station_id  \
# 0  0004E44D48763B0A  20230323          5442.05        5235.05
# 1  0006E43813497C0A  20230302          4700.06        5489.03
# 2  00085B799B264179  20230321          5430.08        4748.07
# 3  00101FB18EF7DF09  20230329          5303.06        5303.08
# 4  0010A66E9AB7400A  20230312          4507.07        4441.06
#
#            started_at            ended_at  start_lat  start_lng    end_lat  \
# 0 2023-03-23 20:11:29 2023-03-23 20:20:44  40.719155 -73.948853  40.712604
# 1 2023-03-02 17:18:46 2023-03-02 17:33:01  40.696075 -73.978014  40.720367
# 2 2023-03-21 18:30:17 2023-03-21 18:45:41  40.719115 -74.006666  40.696232
# 3 2023-03-29 20:29:01 2023-03-29 20:31:34  40.715595 -73.987029  40.714274
# 4 2023-03-12 22:19:14 2023-03-12 22:24:19  40.689245 -73.905416  40.686630
#
#      end_lng member_casual
# 0 -73.962644        member
# 1 -73.961650        casual
# 2 -73.991420        casual
# ...

# %%
bike_trip_facts.shape
# Out:
# (2194214, 11)

# %%
bike_trip_facts.drop_duplicates().shape
# Out:
# (2194214, 11)

# %%
bike_trip_facts.isna().sum()
# Out:
# trip_id                0
# date_id                0
# start_station_id     190
# end_station_id      5794
# started_at             0
# ended_at               0
# start_lat              0
# start_lng              0
# end_lat             1481
# end_lng             1481
# member_casual          0
# dtype: int64

# %%
date_dim = pd.read_sql_query('SELECT * FROM date_dimension', con=engine)

# %%
date_dim
# Out:
#      date_id        date  day  month  year  weekday
# 0   20230328  2023-03-28   28      3  2023        2
# 1   20230311  2023-03-11   11      3  2023        6
# 2   20230305  2023-03-05    5      3  2023        0
# 3   20230314  2023-03-14   14      3  2023        2
# 4   20230302  2023-03-02    2      3  2023        4
# 5   20230317  2023-03-17   17      3  2023        5
# 6   20230321  2023-03-21   21      3  2023        2
# 7   20230316  2023-03-16   16      3  2023        4
# 8   20230312  2023-03-12   12      3  2023        0
# 9   20230308  2023-03-08    8      3  2023        3
# 10  20230326  2023-03-26   26      3  2023        0
# 11  20230313  2023-03-13   13      3  2023        1
# 12  20230325  2023-03-25   25      3  2023        6
# 13  20230306  2023-03-06    6      3  2023        1
# 14  20230330  2023-03-30   30      3  2023        4
# 15  20230309  2023-03-09    9      3  2023        4
# 16  20230329  2023-03-29   29      3  2023        3
# ...

# %%
date_dim.shape
# Out:
# (31, 6)

# %%
date_dim.drop_duplicates().shape
# Out:
# (31, 6)

# %%
date_dim.isna().sum()
# Out:
# date_id    0
# date       0
# day        0
# month      0
# year       0
# weekday    0
# dtype: int64

# %%
station_dim = pd.read_sql_query('SELECT * FROM station_dimension', con=engine)

# %%
station_dim
# Out:
#                                 station_id  \
# 0     afd76a0e-ceb8-4d18-a427-b378c4d07a75
# 1     66dc0bbd-0aca-11e7-82f6-3863bb44ef7c
# 2     03872f6b-a522-4c41-a4f2-5d0c41779e7b
# 3     bdcbd89b-9ae0-461b-aa1d-7db7ead07400
# 4     40eaa69a-d3ab-48fc-b395-b5bdc6a1aa85
# ...                                    ...
# 1861  66dc36c3-0aca-11e7-82f6-3863bb44ef7c
# 1862  66db6cd4-0aca-11e7-82f6-3863bb44ef7c
# 1863  66dc8527-0aca-11e7-82f6-3863bb44ef7c
# 1864  66dd52c8-0aca-11e7-82f6-3863bb44ef7c
# 1865  e25f8dee-c110-489f-a978-464ac5c84ca2
#
#                                external_id  electric_bike_surcharge_waiver  \
# 0     afd76a0e-ceb8-4d18-a427-b378c4d07a75                           False
# 1     66dc0bbd-0aca-11e7-82f6-3863bb44ef7c                           False
# 2     03872f6b-a522-4c41-a4f2-5d0c41779e7b                           False
# 3     bdcbd89b-9ae0-461b-aa1d-7db7ead07400                           False
# ...

# %%
station_dim.isna().sum()
# Out:
# station_id                        0
# external_id                       0
# electric_bike_surcharge_waiver    0
# short_name                        0
# eightd_has_key_dispenser          0
# name                              0
# lat                               0
# lon                               0
# region_id                         0
# capacity                          0
# has_kiosk                         0
# station_type                      0
# rental_methods                    0
# legacy_id                         0
# dtype: int64

# %%
station_dim.shape
# Out:
# (1866, 14)

# %%
station_dim.drop_duplicates().shape
# Out:
# (1866, 14)

# %%
station_information = pd.read_sql_query('SELECT * FROM station_information', con=engine)

# %%
station_information
# Out:
#                                external_id  \
# 0     66de19ab-0aca-11e7-82f6-3863bb44ef7c
# 1     66dd26f9-0aca-11e7-82f6-3863bb44ef7c
# 2     66dd3e14-0aca-11e7-82f6-3863bb44ef7c
# 3     0dd71c6d-11ee-4ad4-ba99-36b9ad36112c
# 4     bc9c9006-3d40-400d-8b5c-17f56e6dfcee
# ...                                    ...
# 1861  519824e4-69ba-4270-a395-17c204f328f8
# 1862  cbc48689-7805-49dd-9669-5471f4b7b6fb
# 1863  66dddd28-0aca-11e7-82f6-3863bb44ef7c
# 1864  b6a13f2b-deb4-4f4d-9d67-7d23bee27c88
# 1865  5aa81a37-ea1d-4bf6-ab40-4751c6b4fb08
#
#                                 station_id  electric_bike_surcharge_waiver  \
# 0     66de19ab-0aca-11e7-82f6-3863bb44ef7c                           False
# 1     66dd26f9-0aca-11e7-82f6-3863bb44ef7c                           False
# 2     66dd3e14-0aca-11e7-82f6-3863bb44ef7c                           False
# 3     0dd71c6d-11ee-4ad4-ba99-36b9ad36112c                           False
# ...

# %%
station_dim.shape
# Out:
# (1866, 14)

# %%
station_dim.drop_duplicates().shape
# Out:
# (1866, 14)

# %%
station_dim.isna().sum()
# Out:
# station_id                        0
# external_id                       0
# electric_bike_surcharge_waiver    0
# short_name                        0
# eightd_has_key_dispenser          0
# name                              0
# lat                               0
# lon                               0
# region_id                         0
# capacity                          0
# has_kiosk                         0
# station_type                      0
# rental_methods                    0
# legacy_id                         0
# dtype: int64
